# %% [markdown]
# <a href="https://colab.research.google.com/github/DILEEP-DXD/Colab-notes/blob/main/Logistic_regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import math

x=np.array([1,2,3,4,5,6])
y=np.array([0,0,0,1,1,1])

w=0
b=0

learning_rate=0.1

epochs=1000

def sigmoid(z):
  return 1/(1+np.exp(-z))

for i in range(epochs):
  z=w*x+b
  y_pred=sigmoid(z)
  dw=np.mean((y_pred-y)*x)
  db=np.mean(y_pred-y)

  w=w-learning_rate*dw
  b=b-learning_rate*db

print("Weight:",w)
print("Bias:",b)

def predict(hours):
  z=w*hours+b
  probability=sigmoid(z)

  if probability>=0.5:
    result=1
  else:
    result=0
  return probability,result

for hours in [2,3,4,5,6]:
  probability,result=predict(hours)

  print(
      "Study Hours:",hours,
      "Probability:",round(probability,2),
      "Result:",result
  )
# Out:
# Weight: 1.7036105175157013
# Bias: -5.690294412813251
# Study Hours: 2 Probability: 0.09 Result: 0
# Study Hours: 3 Probability: 0.36 Result: 0
# Study Hours: 4 Probability: 0.75 Result: 1
# Study Hours: 5 Probability: 0.94 Result: 1
# Study Hours: 6 Probability: 0.99 Result: 1
